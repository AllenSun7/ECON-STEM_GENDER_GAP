# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from plotly.offline import iplot
import seaborn as sns

from collections import Counter

# %% [markdown]
# # 1. Data Overview

# %%
# load data
df = pd.read_csv('data/usa_01.csv')
df
# Out:
#           YEAR  SEX  AGE  RACE  RACED  CITIZEN  GRADEATT  GRADEATTD  DEGFIELD  \
# 0         2009    1   51     1    100        0         0          0         0
# 1         2009    2   64     1    100        0         0          0         0
# 2         2009    1   68     1    100        0         0          0         0
# 3         2009    2   61     2    200        0         0          0         0
# 4         2009    1   38     2    200        0         0          0         0
# ...        ...  ...  ...   ...    ...      ...       ...        ...       ...
# 31290938  2018    2    9     1    100        0         3         33         0
# 31290939  2018    2    7     1    100        0         3         31         0
# 31290940  2018    2   49     1    100        0         0          0         0
# 31290941  2018    2   19     1    100        0         0          0         0
# 31290942  2018    1   71     1    100        0         0          0         0
#
#           DEGFIELDD   OCC  UHRSWORK  INCWAGE
# 0                 0     0         0        0
# 1                 0  5310        40    27100
# 2                 0  6200        40    22100
# 3                 0  4020        32     6000
# 4                 0  5350        40    14000
# ...             ...   ...       ...      ...
# 31290938          0     0         0   999999
# 31290939          0     0         0   999999
# 31290940          0  3603        40    18500
# 31290941          0  4255        40    11500
# 31290942          0     0         0        0
#
# [31290943 rows x 13 columns]

# %%
df = df.drop(columns=['RACED', 'GRADEATTD', 'DEGFIELDD', 'GRADEATT'])
df
# Out:
#           YEAR  SEX  AGE  RACE  CITIZEN  GRADEATT  DEGFIELD   OCC  UHRSWORK  \
# 0         2009    1   51     1        0         0         0     0         0
# 1         2009    2   64     1        0         0         0  5310        40
# 2         2009    1   68     1        0         0         0  6200        40
# 3         2009    2   61     2        0         0         0  4020        32
# 4         2009    1   38     2        0         0         0  5350        40
# ...        ...  ...  ...   ...      ...       ...       ...   ...       ...
# 31290938  2018    2    9     1        0         3         0     0         0
# 31290939  2018    2    7     1        0         3         0     0         0
# 31290940  2018    2   49     1        0         0         0  3603        40
# 31290941  2018    2   19     1        0         0         0  4255        40
# 31290942  2018    1   71     1        0         0         0     0         0
#
#           INCWAGE
# 0               0
# 1           27100
# 2           22100
# 3            6000
# 4           14000
# ...           ...
# 31290938   999999
# 31290939   999999
# 31290940    18500
# 31290941    11500
# 31290942        0
#
# [31290943 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6941738 entries, 26 to 31290936
# Data columns (total 13 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   YEAR       int64
#  1   SEX        object
#  2   AGE        int64
#  3   RACE       int64
#  4   RACED      int64
#  5   CITIZEN    int64
#  6   GRADEATT   int64
#  7   GRADEATTD  int64
#  8   DEGFIELD   object
#  9   DEGFIELDD  int64
#  10  OCC        object
#  11  UHRSWORK   int64
#  12  INCWAGE    int64
# dtypes: int64(10), object(3)
# memory usage: 741.5+ MB

# %%
df.isnull().sum(axis = 0)
# Out:
# YEAR         0
# SEX          0
# AGE          0
# RACE         0
# RACED        0
# CITIZEN      0
# GRADEATT     0
# GRADEATTD    0
# DEGFIELD     0
# DEGFIELDD    0
# OCC          0
# UHRSWORK     0
# INCWAGE      0
# dtype: int64

# %% [markdown]
# ## Data  Copy

# %%
import copy
df_origin = copy.deepcopy(df)

# %%
import copy
df = copy.deepcopy(df_origin)

# %% [markdown]
# # 2. Data Preprocessing

# %% [markdown]
# ## 2.1 Decipher Preparation

# %% [markdown]
# ### 2.1.1 Major-DEGFIELD

# %%
df_major = pd.read_csv('src/major.csv')
df_major.head()
# Out:
#    Percent           N  Value                                   Label  STEM
# 0     77.8  24,349,205      0                                     NaN     0
# 1      0.3      84,110     11                             Agriculture     0
# 2      0.1      45,157     13       Environment and Natural Resources     0
# 3      0.2      48,911     14                            Architecture     1
# 4      0.1      22,055     15  Area, Ethnic, and Civilization Studies     0

# %%
stem_values = list(Counter(df_major[df_major['STEM']==1]['Value']).keys())
stem_values
# Out:
# [14, 20, 21, 24, 25, 29, 34, 35, 36, 37, 50, 51, 55, 57, 59, 61]

# %% [markdown]
# ## 2.2 Code Interpretation

# %%
# sex
df['SEX'] = df['SEX'].apply(lambda x: 'Male' if str(x) == '1' else 'Femal')
# major
df['DEGFIELD'] = df['DEGFIELD'].apply(lambda x: np.nan if int(x) == 0 else 'STEM' if x in stem_values else 'Non-STEM')
# usual work hours per week
df['UHRSWORK'] = df['UHRSWORK'].apply(lambda x: np.nan if int(x) == 0 else '<40' if int(x) < 40 else '=40' if int(x) == 40 else '>40')
# occupation
df['OCC'] = df['OCC'].apply(lambda x: np.nan if x == 0 'STEM' if x in range(1000, 2000) else 'Non-STEM')
# income of wage and salary
df['INCWAGE'] = df['INCWAGE'].apply(lambda x: np.nan if x == 0 else x)
# income of wage and salary
df['GRADEATT'] = df['GRADEATT'].apply(lambda x: np.nan if x == 0 else x)


df
# Out:
#           YEAR    SEX  AGE  RACE  CITIZEN  GRADEATT DEGFIELD   OCC UHRSWORK  \
# 0         2009   Male   51     1        0         0      NaN     0      NaN
# 1         2009  Femal   64     1        0         0      NaN  5310      =40
# 2         2009   Male   68     1        0         0      NaN  6200      =40
# 3         2009  Femal   61     2        0         0      NaN  4020      <40
# 4         2009   Male   38     2        0         0      NaN  5350      =40
# ...        ...    ...  ...   ...      ...       ...      ...   ...      ...
# 31290938  2018  Femal    9     1        0         3      NaN     0      NaN
# 31290939  2018  Femal    7     1        0         3      NaN     0      NaN
# 31290940  2018  Femal   49     1        0         0      NaN  3603      =40
# 31290941  2018  Femal   19     1        0         0      NaN  4255      =40
# 31290942  2018   Male   71     1        0         0      NaN     0      NaN
#
#           INCWAGE
# 0               0
# 1           27100
# 2           22100
# 3            6000
# 4           14000
# ...           ...
# 31290938   999999
# 31290939   999999
# 31290940    18500
# 31290941    11500
# 31290942        0
#
# [31290943 rows x 10 columns]

# %% [markdown]
# ### Revise range

# %%
#
df['OCC'] = df['OCC'].apply(lambda x: 'STEM'if x in range(1000, 2000) else 'Non-STEM')
df['OCC']
# Out:
# 0           Non-STEM
# 1           Non-STEM
# 2           Non-STEM
# 3           Non-STEM
# 4           Non-STEM
#               ...
# 31290938    Non-STEM
# 31290939    Non-STEM
# 31290940    Non-STEM
# 31290941    Non-STEM
# 31290942    Non-STEM
# Name: OCC, Length: 31290943, dtype: object

# %%
Counter(df['OCC'])
# Out:
# Counter({'Non-STEM': 30364353, 'STEM': 926590})

# %% [markdown]
# ## 2.? Drop nan values

# %%
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6941738 entries, 26 to 31290936
# Data columns (total 13 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   YEAR       int64
#  1   SEX        object
#  2   AGE        int64
#  3   RACE       int64
#  4   RACED      int64
#  5   CITIZEN    int64
#  6   GRADEATT   int64
#  7   GRADEATTD  int64
#  8   DEGFIELD   object
#  9   DEGFIELDD  int64
#  10  OCC        object
#  11  UHRSWORK   int64
#  12  INCWAGE    int64
# dtypes: int64(10), object(3)
# memory usage: 741.5+ MB

# %% [markdown]
# # 3. Data Visualization

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pl
import matplotlib.ticker as tick

# Auto adjust unit of y Axis
def y_fmt(tick_val, pos):
    if tick_val >= 1000000:
        val = int(tick_val)/1000000
        return '{:.1f} M'.format(val)
    elif tick_val >= 1000:
        val = int(tick_val) / 1000
        return '{:.1f} K'.format(val)
    else:
        return tick_val

# plt.figure(figsize=[60,30])
ax = sns.countplot(x='YEAR', data=df, palette="Blues_d")
ax = pl.gca()
ax.yaxis.set_major_formatter(tick.FuncFormatter(y_fmt))
ax.set_ylabel('Population')
ax.set_xlabel("Year")
ax.axes.set_title("Population of Sample for Each Year")
# ax.tick_params(labelsize=40)
# plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Sex VS Year

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pl
import matplotlib.ticker as tick

# Auto adjust unit of y Axis
def y_fmt(tick_val, pos):
    if tick_val >= 1000000:
        val = int(tick_val)/1000000
        return '{:.1f} M'.format(val)
    elif tick_val >= 1000:
        val = int(tick_val) / 1000
        return '{:.1f} K'.format(val)
    else:
        return tick_val

# plt.figure(figsize=[60,30])
ax = sns.countplot(x='YEAR', hue='SEX', data=df)
ax = pl.gca()
ax.yaxis.set_major_formatter(tick.FuncFormatter(y_fmt))
ax.set_ylabel('Population')
ax.set_xlabel('Year')
ax.axes.set_title('SEX Comparison for Each Year')
# ax.tick_params(labelsize=40)
# plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Major VS SEX

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pl
import matplotlib.ticker as tick

# Auto adjust unit of y Axis
def y_fmt(tick_val, pos):
    if tick_val >= 1000000:
        val = int(tick_val)/1000000
        return '{:.1f} M'.format(val)
    elif tick_val >= 1000:
        val = int(tick_val) / 1000
        return '{:.1f} K'.format(val)
    else:
        return tick_val

# plt.figure(figsize=[60,30])
ax = sns.countplot(x='YEAR', hue='DEGFIELD', data=df)
ax = pl.gca()
ax.yaxis.set_major_formatter(tick.FuncFormatter(y_fmt))
ax.set_ylabel('Population')
ax.set_xlabel('Year')
ax.axes.set_title('DEGFIELD Comparison for Each Year')
# ax.tick_params(labelsize=40)
# plt.xticks(rotation=45)
plt.show()

# %%
occupations = dict(Counter(df['OCC']))
occupations_years = dict()
for o in occupations.keys():
    years = dict(zip(Counter(df['YEAR']).keys(), [0]*len(Counter(df['YEAR']).keys())))
    years_new = dict(Counter(df[df['OCC']==o]['YEAR']))
    for y in years:
        years[y] += years_new[y]
    occupations_years[o] = years
occupations_years
# Out:
# {'Non-STEM': {2009: 565167,
#   2010: 580780,
#   2011: 573137,
#   2012: 594301,
#   2013: 622360,
#   2014: 633923,
#   2015: 652159,
#   2016: 674484,
#   2017: 699177,
#   2018: 720011},
#  'STEM': {2009: 58156,
#   2010: 56425,
#   2011: 54004,
#   2012: 56636,
#   2013: 60968,
#   2014: 61729,
#   2015: 64468,
#   2016: 68042,
#   2017: 71472,
#   2018: 74339}}

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pl
import matplotlib.ticker as tick

# Auto adjust unit of y Axis
def y_fmt(tick_val, pos):
    if tick_val >= 1000000:
        val = int(tick_val)/1000000
        return '{:.1f} M'.format(val)
    elif tick_val >= 1000:
        val = int(tick_val) / 1000
        return '{:.1f} K'.format(val)
    else:
        return tick_val

# plt.figure(figsize=[60,30])
ax = sns.lineplot(x=list(occupations_years['STEM'].keys()), y=list(occupations_years['STEM'].values()))
ax = pl.gca()
ax.yaxis.set_major_formatter(tick.FuncFormatter(y_fmt))
ax.set_ylabel('Population')
ax.set_xlabel('Year')
ax.axes.set_title('Occupation Comparison for Each Year')
# ax.tick_params(labelsize=40)
# plt.xticks(rotation=45)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pl
import matplotlib.ticker as tick

# Auto adjust unit of y Axis
def y_fmt(tick_val, pos):
    if tick_val >= 1000000:
        val = int(tick_val)/1000000
        return '{:.1f} M'.format(val)
    elif tick_val >= 1000:
        val = int(tick_val) / 1000
        return '{:.1f} K'.format(val)
    else:
        return tick_val

# plt.figure(figsize=[60,30])
ax = sns.countplot(x='YEAR', hue='OCC', data=df)
ax = pl.gca()
ax.yaxis.set_major_formatter(tick.FuncFormatter(y_fmt))
ax.set_ylabel('YEAR')
ax.set_xlabel('Year')
ax.axes.set_title('Occupation Comparison for Each Year')
# ax.tick_params(labelsize=40)
# plt.xticks(rotation=45)
plt.show()
